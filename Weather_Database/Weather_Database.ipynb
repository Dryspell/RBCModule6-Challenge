# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
def make_rand_coords(number):
    print('making random coordinates')
    lats = np.random.uniform(low=-90.000, high=90.000, size=number)
    lngs = np.random.uniform(low=-180.000, high=180.000, size=number)
    lat_lngs = zip(lats, lngs)
    return list(lat_lngs)

# %%
from citipy import citipy

# %%
def get_rand_cities(number):
    print('associating city names with random coordinates')
    cities = []
    
    for coordinate in make_rand_coords(number):
        city = (citipy.nearest_city(coordinate[0],coordinate[1]).city_name,
              citipy.nearest_city(coordinate[0],coordinate[1]).country_code)
        
        # Create a list for holding the cities.
        if city not in cities:
            cities.append(city)
    # Print the city count to confirm sufficient count.
    print(f"Found {len(cities)} cities from {number} random coordinates")
    print(cities)
    return cities

get_rand_cities(10)
# Out:
# associating city names with random coordinates
# making random coordinates
# Found 10 cities from 10 random coordinates
# [('souillac', 'mu'), ('deputatskiy', 'ru'), ('sao felix do xingu', 'br'), ('kirakira', 'sb'), ('new norfolk', 'au'), ('narsaq', 'gl'), ('college', 'us'), ('atuona', 'pf'), ('rikitea', 'pf'), ('rawson', 'ar')]
# [('souillac', 'mu'),
#  ('deputatskiy', 'ru'),
#  ('sao felix do xingu', 'br'),
#  ('kirakira', 'sb'),
#  ('new norfolk', 'au'),
#  ('narsaq', 'gl'),
#  ('college', 'us'),
#  ('atuona', 'pf'),
#  ('rikitea', 'pf'),
#  ('rawson', 'ar')]

# %%
import requests
requests.__version__
# Out:
# '2.26.0'

# %%
# Import the requests library.
# Import the API key.
from config import weather_api_key
import time
from datetime import datetime
import json

# %%
def get_weather(cities):
    print(type(cities))
    if type(cities) != type([]):
        print('Sorry, that is not a list of cities')
        return
    
    # Starting URL for Weather Map API Call.
    url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

    # Create an empty list to hold the weather data.
    city_data = []
    cities_not_found = []
    # Print the beginning of the logging.
    print("Beginning Data Retrieval     ")
    print("-----------------------------")

    # Create counters.
    record_count = 1
    set_count = 1
    
    # Loop through all the cities in the list.
    for i, city in enumerate(cities):

        # Group cities in sets of 50 for logging purposes.
        if (i % 50 == 0 and i >= 50):
            set_count += 1
            record_count = 1
            time.sleep(60)

        # Create endpoint URL with each city.
        city_url = f"{url}&q={city[0]},,{city[1]}"

        # Log the URL, record, and set numbers and the city.
        print(f"Processing Record {record_count} of Set {set_count} | {city}")
        # Add 1 to the record count.
        record_count += 1

        # Run an API request for each of the cities.
        try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
            #print(json.dumps(city_weather, indent=3))
            # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            # Append the city information into city_data list.
            city_data.append({"City": city_weather['name'],
                              "Lat": city_weather["coord"]["lat"],
                              "Lng": city_weather["coord"]["lon"],
                              "Max Temp": city_weather["main"]["temp_max"],
                              "Humidity": city_weather["main"]["humidity"],
                              "Cloudiness": city_weather["clouds"]["all"],
                              "Wind Speed": city_weather["wind"]["speed"],
                              "Country": city_weather["sys"]["country"],
                              "Date": city_date})

        # If an error is experienced, skip the city.
        except KeyError:
            cities_not_found.append(city)
            print(f"City {city} not found. Skipping...")
            pass

    # Indicate that Data Loading is complete.
    print("-----------------------------")
    print("Data Retrieval Complete      ")
    print("-----------------------------")
    
    # Convert the array of dictionaries to a Pandas DataFrame.
    city_data_df = pd.DataFrame(city_data)
    #print(city_data_df.head(10))
    
    # Create the output file (CSV).
    output_data_file = "WeatherPy_Database.csv"
    # Export the City_Data into a CSV.
    city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
get_weather(get_rand_cities(2000))
# Out:
# associating city names with random coordinates
# making random coordinates
# Found 775 cities from 2000 random coordinates
# [('ixtapa', 'mx'), ('karaton', 'kz'), ('ushuaia', 'ar'), ('busselton', 'au'), ('pacific grove', 'us'), ('darya khan mari', 'pk'), ('venado tuerto', 'ar'), ('bredasdorp', 'za'), ('mataura', 'pf'), ('stoyba', 'ru'), ('jamestown', 'sh'), ('vaini', 'to'), ('egana', 'ph'), ('macheng', 'cn'), ('umzimvubu', 'za'), ('keti bandar', 'pk'), ('victoria', 'sc'), ('truro', 'ca'), ('punta arenas', 'cl'), ('nikolskoye', 'ru'), ('bambous virieux', 'mu'), ('kapaa', 'us'), ('fairbanks', 'us'), ('satitoa', 'ws'), ('talnakh', 'ru'), ('kirakira', 'sb'), ('ksenyevka', 'ru'), ('yaan', 'cn'), ('avarua', 'ck'), ('rikitea', 'pf'), ('lithgow', 'au'), ('albany', 'au'), ('hambantota', 'lk'), ('tessalit', 'ml'), ('hobart', 'au'), ('belushya guba', 'ru'), ('arraial do cabo', 'br'), ('chokurdakh', 'ru'), ('espanola', 'ca'), ('thompson', 'ca'), ('christchurch', 'nz'), ('saint-philippe', 're'), ('vaitupu', 'wf'), ('saskylakh', 'ru'), ('la palma', 'pa'), ('barrow', 'us'), ('tazovskiy', 'ru'), ('nizhneyansk', 'ru'), ('tumannyy', 'ru'), ('cape town', 'za'), ('nan', 'th'), ('mar del plata', 'ar'), ('khatanga', 'ru'), ('dingle', 'ie'), ('katsuura', 'jp'), ('ahipara', 'nz'), ('hilo', 'us'), ('pevek', 'ru'), ('namibe', 'ao'), ('ilanskiy', 'ru'), ('san ignacio', 'bz'), ('hong gai', 'vn'), ('provideniya', 'ru'), ('esperance', 'au'), ('borogontsy', 'ru'), ('norman wells', 'ca'), ('hermanus', 'za'), ('morehead', 'pg'), ('bengkulu', 'id'), ('barinas', 've'), ('yumen', 'cn'), ('tual', 'id'), ('tirumullaivasal', 'in'), ('port-gentil', 'ga'), ('airai', 'pw'), ('prince rupert', 'ca'), ('puerto ayora', 'ec'), ('omboue', 'ga'), ('tsihombe', 'mg'), ('bluff', 'nz'), ('namatanai', 'pg'), ('hay river', 'ca'), ('la ronge', 'ca'), ('kirensk', 'ru'), ('port hardy', 'ca'), ('kampot', 'kh'), ('hirara', 'jp'), ('biak', 'id'), ('rudnogorsk', 'ru'), ('keshan', 'cn'), ('pagouria', 'gr'), ('dikson', 'ru'), ('petropavlovsk-kamchatskiy', 'ru'), ('hamilton', 'bm'), ('cherskiy', 'ru'), ('leningradskiy', 'ru'), ('karasuk', 'ru'), ('bairiki', 'ki'), ('daoukro', 'ci'), ('concepcion del oro', 'mx'), ('bagaciu', 'ro'), ('hermiston', 'us'), ('barentsburg', 'sj'), ('bilma', 'ne'), ('san andres', 'co'), ('barahona', 'do'), ('neiafu', 'to'), ('padang', 'id'), ('shenjiamen', 'cn'), ('tiksi', 'ru'), ('copiapo', 'cl'), ('nome', 'us'), ('high rock', 'bs'), ('shchelyayur', 'ru'), ('atka', 'ru'), ('tiznit', 'ma'), ('septemes-les-vallons', 'fr'), ('marsh harbour', 'bs'), ('bilibino', 'ru'), ('taolanaro', 'mg'), ('roma', 'au'), ('moron', 'mn'), ('illoqqortoormiut', 'gl'), ('qaanaaq', 'gl'), ('vilyuysk', 'ru'), ('carnarvon', 'au'), ('grivenskaya', 'ru'), ('bosobolo', 'cd'), ('makinsk', 'kz'), ('berlevag', 'no'), ('axim', 'gh'), ('butaritari', 'ki'), ('touros', 'br'), ('ambikapur', 'in'), ('amderma', 'ru'), ('kajaani', 'fi'), ('tuatapere', 'nz'), ('sao filipe', 'cv'), ('saint simons', 'us'), ('kez', 'ru'), ('jurilovca', 'ro'), ('ust-kut', 'ru'), ('khalimbekaul', 'ru'), ('tuktoyaktuk', 'ca'), ('keetmanshoop', 'na'), ('guerrero negro', 'mx'), ('diffa', 'ne'), ('vao', 'nc'), ('katha', 'mm'), ('sibolga', 'id'), ('codrington', 'ag'), ('northam', 'au'), ('grand river south east', 'mu'), ('yellowknife', 'ca'), ('kaitangata', 'nz'), ('belmonte', 'br'), ('lagoa', 'pt'), ('vestmannaeyjar', 'is'), ('atuona', 'pf'), ('goderich', 'sl'), ('evensk', 'ru'), ('kashi', 'cn'), ('ondangwa', 'na'), ('doka', 'sd'), ('mezen', 'ru'), ('ribeira grande', 'pt'), ('tahoua', 'ne'), ('kalmunai', 'lk'), ('moerai', 'pf'), ('kathmandu', 'np'), ('half moon bay', 'us'), ('vanavara', 'ru'), ('san patricio', 'mx'), ('london', 'gb'), ('port blair', 'in'), ('santa maria', 'cv'), ('port alfred', 'za'), ('gander', 'ca'), ('mount gambier', 'au'), ('inongo', 'cd'), ('margate', 'za'), ('sentyabrskiy', 'ru'), ('oktyabrskoye', 'ru'), ('port elizabeth', 'za'), ('konin', 'pl'), ('vitim', 'ru'), ('souillac', 'mu'), ('faanui', 'pf'), ('pisco', 'pe'), ('sioux lookout', 'ca'), ('husavik', 'is'), ('sitka', 'us'), ('castro', 'cl'), ('venustiano carranza', 'mx'), ('lav ...
# <class 'list'>
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ('ixtapa', 'mx')
# Processing Record 2 of Set 1 | ('karaton', 'kz')
# Processing Record 3 of Set 1 | ('ushuaia', 'ar')
# Processing Record 4 of Set 1 | ('busselton', 'au')
# Processing Record 5 of Set 1 | ('pacific grove', 'us')
# Processing Record 6 of Set 1 | ('darya khan mari', 'pk')
# City ('darya khan mari', 'pk') not found. Skipping...
# Processing Record 7 of Set 1 | ('venado tuerto', 'ar')
# Processing Record 8 of Set 1 | ('bredasdorp', 'za')
# Processing Record 9 of Set 1 | ('mataura', 'pf')
# Processing Record 10 of Set 1 | ('stoyba', 'ru')
# City ('stoyba', 'ru') not found. Skipping...
# Processing Record 11 of Set 1 | ('jamestown', 'sh')
# Processing Record 12 of Set 1 | ('vaini', 'to')
# Processing Record 13 of Set 1 | ('egana', 'ph')
# Processing Record 14 of Set 1 | ('macheng', 'cn')
# Processing Record 15 of Set 1 | ('umzimvubu', 'za')
# City ('umzimvubu', 'za') not found. Skipping...
# Processing Record 16 of Set 1 | ('keti bandar', 'pk')
# Processing Record 17 of Set 1 | ('victoria', 'sc')
# Processing Record 18 of Set 1 | ('truro', 'ca')
# Processing Record 19 of Set 1 | ('punta arenas', 'cl')
# Processing Record 20 of Set 1 | ('nikolskoye', 'ru')
# Processing Record 21 of Set 1 | ('bambous virieux', 'mu')
# Processing Record 22 of Set 1 | ('kapaa', 'us')
# Processing Record 23 of Set 1 | ('fairbanks', 'us')
# Processing Record 24 of Set 1 | ('satitoa', 'ws')
# City ('satitoa', 'ws') not found. Skipping...
# Processing Record 25 of Set 1 | ('talnakh', 'ru')
# Processing Record 26 of Set 1 | ('kirakira', 'sb')
# Processing Record 27 of Set 1 | ('ksenyevka', 'ru')
# City ('ksenyevka', 'ru') not found. Skipping...
# Processing Record 28 of Set 1 | ('yaan', 'cn')
# Processing Record 29 of Set 1 | ('avarua', 'ck')
# Processing Record 30 of Set 1 | ('rikitea', 'pf')
# Processing Record 31 of Set 1 | ('lithgow', 'au')
# Processing Record 32 of Set 1 | ('albany', 'au')
# Processing Record 33 of Set 1 | ('hambantota', 'lk')
# Processing Record 34 of Set 1 | ('tessalit', 'ml')
# Processing Record 35 of Set 1 | ('hobart', 'au')
# Processing Record 36 of Set 1 | ('belushya guba', 'ru')
# City ('belushya guba', 'ru') not found. Skipping...
# Processing Record 37 of Set 1 | ('arraial do cabo', 'br')
# Processing Record 38 of Set 1 | ('chokurdakh', 'ru')
# Processing Record 39 of Set 1 | ('espanola', 'ca')
# Processing Record 40 of Set 1 | ('thompson', 'ca')
# Processing Record 41 of Set 1 | ('christchurch', 'nz')
# Processing Record 42 of Set 1 | ('saint-philippe', 're')
# Processing Record 43 of Set 1 | ('vaitupu', 'wf')
# City ('vaitupu', 'wf') not found. Skipping...
# Processing Record 44 of Set 1 | ('saskylakh', 'ru')
# Processing Record 45 of Set 1 | ('la palma', 'pa')
# Processing Record 46 of Set 1 | ('barrow', 'us')
# Processing Record 47 of Set 1 | ('tazovskiy', 'ru')
# Processing Record 48 of Set 1 | ('nizhneyansk', 'ru')
# City ('nizhneyansk', 'ru') not found. Skipping...
# Processing Record 49 of Set 1 | ('tumannyy', 'ru')
# City ('tumannyy', 'ru') not found. Skipping...
# Processing Record 50 of Set 1 | ('cape town', 'za')
# Processing Record 1 of Set 2 | ('nan', 'th')
# Processing Record 2 of Set 2 | ('mar del plata', 'ar')
# Processing Record 3 of Set 2 | ('khatanga', 'ru')
# Processing Record 4 of Set 2 | ('dingle', 'ie')
# Processing Record 5 of Set 2 | ('katsuura', 'jp')
# Processing Record 6 of Set 2 | ('ahipara', 'nz')
# Processing Record 7 of Set 2 | ('hilo', 'us')
# Processing Record 8 of Set 2 | ('pevek', 'ru')
# Processing Record 9 of Set 2 | ('namibe', 'ao')
# Processing Record 10 of Set 2 | ('ilanskiy', 'ru')
# Processing Record 11 of Set 2 | ('san ignacio', 'bz')
# Processing Record 12 of Set 2 | ('hong gai', 'vn')
# Processing Record 13 of Set 2 | ('provideniya', 'ru')
# Processing Record 14 of Set 2 | ('esperance', 'au')
# Processing Record 15 of Set 2 | ('borogontsy', 'ru')
# Processing Record 16 of Set 2 | ('norman wells', 'ca')
# Processing Record 17 of Set 2 | ('hermanus', 'za')
# Processing Record 18 of Set 2 | ('morehead', 'pg')
# Processing Record 19 of Set 2 | ('bengkulu', 'id')
# Processing Record 20 of Set 2 | ('barinas', 've')
# Processing Record 21 of Set 2 | ('yumen', 'cn')
# Processing Record 22 of Set 2 | ('tual', 'id')
# Processing Record 23 of Set 2 | ('tirumullaivasal', 'in')
# Processing Record 24 of Set 2 | ('port-gentil', 'ga')
# Processing Record 25 of Set 2 | ('airai', 'pw')
# Processing Record 26 of Set 2 | ('prince rupert', 'ca')
# Processing Record 27 of Set 2 | ('puerto ayora', 'ec')
# Processing Record 28 of Set 2 | ('omboue', 'ga')
# Processing Record 29 of Set 2 | ('tsihombe', 'mg')
# City ('tsihombe', 'mg') not found. Skipping...
# Processing Record 30 of Set 2 | ('bluff', 'nz')
# Processing Record 31 of Set 2 | ('namatanai', 'pg')
# Processing Record 32 of Set 2 | ('hay river', 'ca')
# Processing Record 33 of Set 2 | ('la ronge', 'ca')
# Processing Record 34 of Set 2 | ('kirensk', 'ru')
# Processing Record 35 of Set 2 | ('port hardy', 'ca')
# Processing Record 36 of Set 2 | ('kampot', 'kh')
# Processing Record 37 of Set 2 | ('hirara', 'jp')
# Processing Record 38 of Set 2 | ('biak', 'id')
# Processing Record 39 of Set 2 | ('rudnogorsk', 'ru')
# Processing Record 40 of Set 2 | ('keshan', 'cn')
# City ('keshan', 'cn') not found. Skipping...
# Processing Record 41 of Set 2 | ('pagouria', 'gr')
# Processing Record 42 of Set 2 | ('dikson', 'ru')
# Processing Record 43 of Set 2 | ('petropavlovsk-kamchatskiy', 'ru')
# Processing Record 44 of Set 2 | ('hamilton', 'bm')
# Processing Record 45 of Set 2 | ('cherskiy', 'ru')
# Processing Record 46 of Set 2 | ('leningradskiy', 'ru')
# Processing Record 47 of Set 2 | ('karasuk', 'ru')
# Processing Record 48 of Set 2 | ('bairiki', 'ki')
# Processing Record 49 of Set 2 | ('daoukro', 'ci')
# Processing Record 50 of Set 2 | ('concepcion del oro', 'mx')
# Processing Record 1 of Set 3 | ('bagaciu', 'ro')
# Processing Record 2 of Set 3 | ('hermiston', 'us')
# Processing Record 3 of Set 3 | ('barentsburg', 'sj')
# City ('barentsburg', 'sj') not found. Skipping...
# Processing Record 4 of Set 3 | ('bilma', 'ne')
# Processing Record 5 of Set 3 | ('san andres', 'co')
# Processing Record 6 of Set 3 | ('barahona', 'do')
# Processing Record 7 of Set 3 | ('neiafu', 'to')
# Processing Record 8 of Set 3 | ('padang', 'id')
# Processing Record 9 of Set 3 | ('shenjiamen', 'cn')
# Processing Record 10 of Set 3 | ('tiksi', 'ru')
# Processing Record 11 of Set 3 | ('copiapo', 'cl')
# Processing Record 12 of Set 3 | ('nome', 'us')
# Processing Record 13 of Set 3 | ('high rock', 'bs')
# Processing Record 14 of Set 3 | ('shchelyayur', 'ru')
# City ('shchelyayur', 'ru') not found. Skipping...
# Processing Record 15 of Set 3 | ('atka', 'ru')
# City ('atka', 'ru') not found. Skipping...
# Processing Record 16 of Set 3 | ('tiznit', 'ma')
# Processing Record 17 of Set 3 | ('septemes-les-vallons', 'fr')
# Processing Record 18 of Set 3 | ('marsh harbour', 'bs')
# Processing Record 19 of Set 3 | ('bilibino', 'ru')
# Processing Record 20 of Set 3 | ('taolanaro', 'mg')
# City ('taolanaro', 'mg') not found. Skipping...
# Processing Record 21 of Set 3 | ('roma', 'au')
# Processing Record 22 of Set 3 | ('moron', 'mn')
# Processing Record 23 of Set 3 | ('illoqqortoormiut', 'gl')
# City ('illoqqortoormiut', 'gl') not found. Skipping...
# Processing Record 24 of Set 3 | ('qaanaaq', 'gl')
# Processing Record 25 of Set 3 | ('vilyuysk', 'ru')
# Processing Record 26 of Set 3 | ('carnarvon', 'au')
# Processing Record 27 of Set 3 | ('grivenskaya', 'ru')
# Processing Record 28 of Set 3 | ('bosobolo', 'cd')
# Processing Record 29 of Set 3 | ('makinsk', 'kz')
# Processing Record 30 of Set 3 | ('berlevag', 'no')
# Processing Record 31 of Set 3 | ('axim', 'gh')
# Processing Record 32 of Set 3 | ('butaritari', 'ki')
# Processing Record 33 of Set 3 | ('touros', 'br')
# Processing Record 34 of Set 3 | ('ambikapur', 'in')
# Processing Record 35 of Set 3 | ('amderma', 'ru')
# City ('amderma', 'ru') not found. Skipping...
# Processing Record 36 of Set 3 | ('kajaani', 'fi')
# Processing Record 37 of Set 3 | ('tuatapere', 'nz')
# Processing Record 38 of Set 3 | ('sao filipe', 'cv')
# Processing Record 39 of Set 3 | ('saint simons', 'us')
# Processing Record 40 of Set 3 | ('kez', 'ru')
# Processing Record 41 of Set 3 | ('jurilovca', 'ro')
# Processing Record 42 of Set 3 | ('ust-kut', 'ru')
# Processing Record 43 of Set 3 | ('khalimbekaul', 'ru')
# Processing Record 44 of Set 3 | ('tuktoyaktuk', 'ca')
# Processing Record 45 of Set 3 | ('keetmanshoop', 'na')
# Processing Record 46 of Set 3 | ('guerrero negro', 'mx')
# Processing Record 47 of Set 3 | ('diffa', 'ne')
# Processing Record 48 of Set 3 | ('vao', 'nc')
# Processing Record 49 of Set 3 | ('katha', 'mm')
# City ('katha', 'mm') not found. Skipping...
# Processing Record 50 of Set 3 | ('sibolga', 'id')
# Processing Record 1 of Set 4 | ('codrington', 'ag')
# Processing Record 2 of Set 4 | ('northam', 'au')
# Processing Record 3 of Set 4 | ('grand river south east', 'mu')
# City ('grand river south east', 'mu') not found. Skipping...
# Processing Record 4 of Set 4 | ('yellowknife', 'ca')
# Processing Record 5 of Set 4 | ('kaitangata', 'nz')
# Processing Record 6 of Set 4 | ('belmonte', 'br')
# Processing Record 7 of Set 4 | ('lagoa', 'pt')
# Processing Record 8 of Set 4 | ('vestmannaeyjar', 'is')
# Processing Record 9 of Set 4 | ('atuona', 'pf')
# Processing Record 10 of Set 4 | ('goderich', 'sl')
# Processing Record 11 of Set 4 | ('evensk', 'ru')
# Processing Record 12 of Set 4 | ('kashi', 'cn')
# Processing Record 13 of Set 4 | ('ondangwa', 'na')
# Processing Record 14 of Set 4 | ('doka', 'sd')
# Processing Record 15 of Set 4 | ('mezen', 'ru')
# Processing Record 16 of Set 4 | ('ribeira grande', 'pt')
# Processing Record 17 of Set 4 | ('tahoua', 'ne')
# Processing Record 18 of Set 4 | ('kalmunai', 'lk')
# Processing Record 19 of Set 4 | ('moerai', 'pf')
# Processing Record 20 of Set 4 | ('kathmandu', 'np')
# Processing Record 21 of Set 4 | ('half moon bay', 'us')
# Processing Record 22 of Set 4 | ('vanavara', 'ru')
# Processing Record 23 of Set 4 | ('san patricio', 'mx')
# Processing Record 24 of Set 4 | ('london', 'gb')
# Processing Record 25 of Set 4 | ('port blair', 'in')
# Processing Record 26 of Set 4 | ('santa maria', 'cv')
# Processing Record 27 of Set 4 | ('port alfred', 'za')
# Processing Record 28 of Set 4 | ('gander', 'ca')
# Processing Record 29 of Set 4 | ('mount gambier', 'au')
# Processing Record 30 of Set 4 | ('inongo', 'cd')
# Processing Record 31 of Set 4 | ('margate', 'za')
# Processing Record 32 of Set 4 | ('sentyabrskiy', 'ru')
# City ('sentyabrskiy', 'ru') not found. Skipping...
# Processing Record 33 of Set 4 | ('oktyabrskoye', 'ru')
# Processing Record 34 of Set 4 | ('port elizabeth', 'za')
# Processing Record 35 of Set 4 | ('konin', 'pl')
# Processing Record 36 of Set 4 | ('vitim', 'ru')
# Processing Record 37 of Set 4 | ('souillac', 'mu')
# Processing Record 38 of Set 4 | ('faanui', 'pf')
# Processing Record 39 of Set 4 | ('pisco', 'pe')
# Processing Record 40 of Set 4 | ('sioux lookout', 'ca')
# Processing Record 41 of Set 4 | ('husavik', 'is')
# Processing Record 42 of Set 4 | ('sitka', 'us')
# Processing Record 43 of Set 4 | ('castro', 'cl')
# Processing Record 44 of Set 4 | ('venustiano carranza', 'mx')
# Processing Record 45 of Set 4 | ('lavrentiya', 'ru')
# Processing Record 46 of Set 4 | ('okhotsk', 'ru')
# Processing Record 47 of Set 4 | ('lebu', 'cl')
# Processing Record 48 of Set 4 | ('nsanje', 'mw')
# Processing Record 49 of Set 4 | ('riachao das neves', 'br')
# Processing Record 50 of Set 4 | ('khovu-aksy', 'ru')
# Processing Record 1 of Set 5 | ('bougouni', 'ml')
# Processing Record 2 of Set 5 | ('new norfolk', 'au')
# Processing Record 3 of Set 5 | ('vila franca do campo', 'pt')
# Processing Record 4 of Set 5 | ('linxia', 'cn')
# Processing Record 5 of Set 5 | ('manggar', 'id')
# Processing Record 6 of Set 5 | ('meulaboh', 'id')
# Processing Record 7 of Set 5 | ('narsaq', 'gl')
# Processing Record 8 of Set 5 | ('agadir', 'ma')
# Processing Record 9 of Set 5 | ('bethel', 'us')
# Processing Record 10 of Set 5 | ('capreol', 'ca')
# Processing Record 11 of Set 5 | ('mys shmidta', 'ru')
# City ('mys shmidta', 'ru') not found. Skipping...
# Processing Record 12 of Set 5 | ('eureka', 'us')
# Processing Record 13 of Set 5 | ('bonavista', 'ca')
# Processing Record 14 of Set 5 | ('mapiripan', 'co')
# Processing Record 15 of Set 5 | ('tamandare', 'br')
# Processing Record 16 of Set 5 | ('toftir', 'fo')
# City ('toftir', 'fo') not found. Skipping...
# Processing Record 17 of Set 5 | ('tinskoy', 'ru')
# Processing Record 18 of Set 5 | ('twentynine palms', 'us')
# Processing Record 19 of Set 5 | ('kamenka', 'ru')
# Processing Record 20 of Set 5 | ('leninsk-kuznetskiy', 'ru')
# Processing Record 21 of Set 5 | ('gunjur', 'gm')
# Processing Record 22 of Set 5 | ('sao joao da barra', 'br')
# Processing Record 23 of Set 5 | ('korla', 'cn')
# Processing Record 24 of Set 5 | ('plainview', 'us')
# Processing Record 25 of Set 5 | ('sherlovaya gora', 'ru')
# Processing Record 26 of Set 5 | ('coquimbo', 'cl')
# Processing Record 27 of Set 5 | ('rio grande', 'br')
# Processing Record 28 of Set 5 | ('kidal', 'ml')
# Processing Record 29 of Set 5 | ('susanville', 'us')
# Processing Record 30 of Set 5 | ('khandyga', 'ru')
# Processing Record 31 of Set 5 | ('chilchotla', 'mx')
# Processing Record 32 of Set 5 | ('itarema', 'br')
# Processing Record 33 of Set 5 | ('karratha', 'au')
# Processing Record 34 of Set 5 | ('vitimskiy', 'ru')
# City ('vitimskiy', 'ru') not found. Skipping...
# Processing Record 35 of Set 5 | ('prieska', 'za')
# Processing Record 36 of Set 5 | ('kaohsiung', 'tw')
# Processing Record 37 of Set 5 | ('fethiye', 'tr')
# Processing Record 38 of Set 5 | ('constitucion', 'mx')
# Processing Record 39 of Set 5 | ('mogzon', 'ru')
# Processing Record 40 of Set 5 | ('upernavik', 'gl')
# Processing Record 41 of Set 5 | ('panama city', 'us')
# Processing Record 42 of Set 5 | ('kawalu', 'id')
# Processing Record 43 of Set 5 | ('matay', 'eg')
# Processing Record 44 of Set 5 | ('clyde river', 'ca')
# Processing Record 45 of Set 5 | ('sinnamary', 'gf')
# Processing Record 46 of Set 5 | ('brae', 'gb')
# Processing Record 47 of Set 5 | ('teknaf', 'bd')
# Processing Record 48 of Set 5 | ('sibsagar', 'in')
# Processing Record 49 of Set 5 | ('horki', 'by')
# Processing Record 50 of Set 5 | ('port shepstone', 'za')
# Processing Record 1 of Set 6 | ('nanortalik', 'gl')
# Processing Record 2 of Set 6 | ('brumunddal', 'no')
# Processing Record 3 of Set 6 | ('hithadhoo', 'mv')
# Processing Record 4 of Set 6 | ('ayr', 'au')
# Processing Record 5 of Set 6 | ('paamiut', 'gl')
# Processing Record 6 of Set 6 | ('chagda', 'ru')
# City ('chagda', 'ru') not found. Skipping...
# Processing Record 7 of Set 6 | ('anloga', 'gh')
# Processing Record 8 of Set 6 | ('otane', 'nz')
# Processing Record 9 of Set 6 | ('lufilufi', 'ws')
# Processing Record 10 of Set 6 | ('pombas', 'cv')
# Processing Record 11 of Set 6 | ('ilulissat', 'gl')
# Processing Record 12 of Set 6 | ('dok kham tai', 'th')
# Processing Record 13 of Set 6 | ('caravelas', 'br')
# Processing Record 14 of Set 6 | ('vagay', 'ru')
# Processing Record 15 of Set 6 | ('novovyazniki', 'ru')
# Processing Record 16 of Set 6 | ('san cristobal', 'ec')
# Processing Record 17 of Set 6 | ('sorland', 'no')
# Processing Record 18 of Set 6 | ('castelnaudary', 'fr')
# Processing Record 19 of Set 6 | ('smolenka', 'ru')
# Processing Record 20 of Set 6 | ('balakhta', 'ru')
# Processing Record 21 of Set 6 | ('chara', 'ru')
# Processing Record 22 of Set 6 | ('skala', 'gr')
# Processing Record 23 of Set 6 | ('severnoye', 'ru')
# Processing Record 24 of Set 6 | ('saleaula', 'ws')
# City ('saleaula', 'ws') not found. Skipping...
# Processing Record 25 of Set 6 | ('port augusta', 'au')
# Processing Record 26 of Set 6 | ('martapura', 'id')
# Processing Record 27 of Set 6 | ('dalbandin', 'pk')
# Processing Record 28 of Set 6 | ('lompoc', 'us')
# Processing Record 29 of Set 6 | ('turukhansk', 'ru')
# Processing Record 30 of Set 6 | ('kautokeino', 'no')
# Processing Record 31 of Set 6 | ('broome', 'au')
# Processing Record 32 of Set 6 | ('maceio', 'br')
# Processing Record 33 of Set 6 | ('yar-sale', 'ru')
# Processing Record 34 of Set 6 | ('luderitz', 'na')
# Processing Record 35 of Set 6 | ('yining', 'cn')
# Processing Record 36 of Set 6 | ('yeppoon', 'au')
# Processing Record 37 of Set 6 | ('manzanillo', 'mx')
# Processing Record 38 of Set 6 | ('torbay', 'ca')
# Processing Record 39 of Set 6 | ('kayerkan', 'ru')
# Processing Record 40 of Set 6 | ('bitkine', 'td')
# Processing Record 41 of Set 6 | ('ocos', 'gt')
# Processing Record 42 of Set 6 | ('big rapids', 'us')
# Processing Record 43 of Set 6 | ('kuche', 'cn')
# City ('kuche', 'cn') not found. Skipping...
# Processing Record 44 of Set 6 | ('tiruvottiyur', 'in')
# City ('tiruvottiyur', 'in') not found. Skipping...
# Processing Record 45 of Set 6 | ('dali', 'cn')
# Processing Record 46 of Set 6 | ('chuy', 'uy')
# Processing Record 47 of Set 6 | ('kruisfontein', 'za')
# Processing Record 48 of Set 6 | ('bahia blanca', 'ar')
# Processing Record 49 of Set 6 | ('rincon', 'an')
# Processing Record 50 of Set 6 | ('severo-kurilsk', 'ru')
# Processing Record 1 of Set 7 | ('acarau', 'br')
# Processing Record 2 of Set 7 | ('atar', 'mr')
# Processing Record 3 of Set 7 | ('kokstad', 'za')
# Processing Record 4 of Set 7 | ('santa eulalia del rio', 'es')
# City ('santa eulalia del rio', 'es') not found. Skipping...
# Processing Record 5 of Set 7 | ('buchanan', 'lr')
# Processing Record 6 of Set 7 | ('dauphin', 'ca')
# Processing Record 7 of Set 7 | ('olafsvik', 'is')
# Processing Record 8 of Set 7 | ('deputatskiy', 'ru')
# Processing Record 9 of Set 7 | ('attawapiskat', 'ca')
# City ('attawapiskat', 'ca') not found. Skipping...
# Processing Record 10 of Set 7 | ('srednekolymsk', 'ru')
# Processing Record 11 of Set 7 | ('antofagasta', 'cl')
# Processing Record 12 of Set 7 | ('begowala', 'pk')
# Processing Record 13 of Set 7 | ('mandalgovi', 'mn')
# Processing Record 14 of Set 7 | ('raudeberg', 'no')
# Processing Record 15 of Set 7 | ('valparaiso', 'us')
# Processing Record 16 of Set 7 | ('matamoros', 'mx')
# Processing Record 17 of Set 7 | ('krasnoselkup', 'ru')
# Processing Record 18 of Set 7 | ('cidreira', 'br')
# Processing Record 19 of Set 7 | ('delijan', 'ir')
# Processing Record 20 of Set 7 | ('lata', 'sb')
# Processing Record 21 of Set 7 | ('chapais', 'ca')
# Processing Record 22 of Set 7 | ('fortuna', 'us')
# Processing Record 23 of Set 7 | ('rudiskes', 'lt')
# Processing Record 24 of Set 7 | ('lakes entrance', 'au')
# Processing Record 25 of Set 7 | ('castlemaine', 'au')
# Processing Record 26 of Set 7 | ('cabo san lucas', 'mx')
# Processing Record 27 of Set 7 | ('joensuu', 'fi')
# Processing Record 28 of Set 7 | ('ca mau', 'vn')
# Processing Record 29 of Set 7 | ('muscat', 'om')
# Processing Record 30 of Set 7 | ('tecoanapa', 'mx')
# Processing Record 31 of Set 7 | ('yerkoy', 'tr')
# Processing Record 32 of Set 7 | ('fuling', 'cn')
# Processing Record 33 of Set 7 | ('necochea', 'ar')
# Processing Record 34 of Set 7 | ('baykit', 'ru')
# Processing Record 35 of Set 7 | ('kysyl-syr', 'ru')
# Processing Record 36 of Set 7 | ('grand forks', 'us')
# Processing Record 37 of Set 7 | ('altamira', 'br')
# Processing Record 38 of Set 7 | ('kiunga', 'pg')
# Processing Record 39 of Set 7 | ('visnes', 'no')
# Processing Record 40 of Set 7 | ('pontianak', 'id')
# Processing Record 41 of Set 7 | ('fort morgan', 'us')
# Processing Record 42 of Set 7 | ('balkhash', 'kz')
# Processing Record 43 of Set 7 | ('omsukchan', 'ru')
# Processing Record 44 of Set 7 | ('nhulunbuy', 'au')
# Processing Record 45 of Set 7 | ('piacabucu', 'br')
# Processing Record 46 of Set 7 | ('shingu', 'jp')
# Processing Record 47 of Set 7 | ('fukue', 'jp')
# Processing Record 48 of Set 7 | ('paita', 'pe')
# Processing Record 49 of Set 7 | ('chegdomyn', 'ru')
# Processing Record 50 of Set 7 | ('palmer', 'us')
# Processing Record 1 of Set 8 | ('kavos', 'gr')
# Processing Record 2 of Set 8 | ('abu kamal', 'sy')
# Processing Record 3 of Set 8 | ('aktash', 'ru')
# Processing Record 4 of Set 8 | ('pafos', 'cy')
# Processing Record 5 of Set 8 | ('rocha', 'uy')
# Processing Record 6 of Set 8 | ('ostersund', 'se')
# Processing Record 7 of Set 8 | ('opunake', 'nz')
# Processing Record 8 of Set 8 | ('aitape', 'pg')
# Processing Record 9 of Set 8 | ('serik', 'tr')
# Processing Record 10 of Set 8 | ('belaya gora', 'ru')
# Processing Record 11 of Set 8 | ('tenosique', 'mx')
# Processing Record 12 of Set 8 | ('gold coast', 'au')
# Processing Record 13 of Set 8 | ('pochutla', 'mx')
# Processing Record 14 of Set 8 | ('arlit', 'ne')
# Processing Record 15 of Set 8 | ('vigrestad', 'no')
# Processing Record 16 of Set 8 | ('east london', 'za')
# Processing Record 17 of Set 8 | ('ushtobe', 'kz')
# Processing Record 18 of Set 8 | ('yabassi', 'cm')
# Processing Record 19 of Set 8 | ('san quintin', 'mx')
# Processing Record 20 of Set 8 | ('nikolayevka', 'ru')
# Processing Record 21 of Set 8 | ('ostrovnoy', 'ru')
# Processing Record 22 of Set 8 | ('kalomo', 'zm')
# City ('kalomo', 'zm') not found. Skipping...
# Processing Record 23 of Set 8 | ('gizo', 'sb')
# Processing Record 24 of Set 8 | ('san angelo', 'us')
# Processing Record 25 of Set 8 | ('novyy urengoy', 'ru')
# Processing Record 26 of Set 8 | ('sangar', 'ru')
# Processing Record 27 of Set 8 | ('hauterive', 'ca')
# Processing Record 28 of Set 8 | ('crib point', 'au')
# Processing Record 29 of Set 8 | ('tasiilaq', 'gl')
# Processing Record 30 of Set 8 | ('mumbwa', 'zm')
# Processing Record 31 of Set 8 | ('hasaki', 'jp')
# Processing Record 32 of Set 8 | ('mahibadhoo', 'mv')
# Processing Record 33 of Set 8 | ('naze', 'jp')
# Processing Record 34 of Set 8 | ('soskovo', 'ru')
# Processing Record 35 of Set 8 | ('dubuque', 'us')
# Processing Record 36 of Set 8 | ('yuryevets', 'ru')
# Processing Record 37 of Set 8 | ('madhogarh', 'in')
# Processing Record 38 of Set 8 | ('pauini', 'br')
# Processing Record 39 of Set 8 | ('benjamin aceval', 'py')
# Processing Record 40 of Set 8 | ('krasnyy', 'ru')
# Processing Record 41 of Set 8 | ('longyearbyen', 'sj')
# Processing Record 42 of Set 8 | ('fray bentos', 'uy')
# Processing Record 43 of Set 8 | ('kakching', 'in')
# Processing Record 44 of Set 8 | ('ponta do sol', 'cv')
# Processing Record 45 of Set 8 | ('uvira', 'cd')
# Processing Record 46 of Set 8 | ('jangaon', 'in')
# Processing Record 47 of Set 8 | ('haines junction', 'ca')
# Processing Record 48 of Set 8 | ('tugolesskiy bor', 'ru')
# Processing Record 49 of Set 8 | ('anadyr', 'ru')
# Processing Record 50 of Set 8 | ('tortoli', 'it')
# Processing Record 1 of Set 9 | ('aykhal', 'ru')
# Processing Record 2 of Set 9 | ('dejen', 'et')
# Processing Record 3 of Set 9 | ('hurghada', 'eg')
# Processing Record 4 of Set 9 | ('tres arroyos', 'ar')
# Processing Record 5 of Set 9 | ('miri', 'my')
# Processing Record 6 of Set 9 | ('bolungarvik', 'is')
# City ('bolungarvik', 'is') not found. Skipping...
# Processing Record 7 of Set 9 | ('asmara', 'er')
# Processing Record 8 of Set 9 | ('zomin', 'uz')
# Processing Record 9 of Set 9 | ('poyarkovo', 'ru')
# Processing Record 10 of Set 9 | ('svetlyy', 'ru')
# Processing Record 11 of Set 9 | ('palabuhanratu', 'id')
# City ('palabuhanratu', 'id') not found. Skipping...
# Processing Record 12 of Set 9 | ('malm', 'no')
# Processing Record 13 of Set 9 | ('tommot', 'ru')
# Processing Record 14 of Set 9 | ('san rafael', 'ar')
# Processing Record 15 of Set 9 | ('sur', 'om')
# Processing Record 16 of Set 9 | ('pangnirtung', 'ca')
# Processing Record 17 of Set 9 | ('oranjemund', 'na')
# Processing Record 18 of Set 9 | ('popondetta', 'pg')
# Processing Record 19 of Set 9 | ('houma', 'us')
# Processing Record 20 of Set 9 | ('mogadishu', 'so')
# Processing Record 21 of Set 9 | ('kirksville', 'us')
# Processing Record 22 of Set 9 | ('tacuarembo', 'uy')
# Processing Record 23 of Set 9 | ('nioro', 'ml')
# Processing Record 24 of Set 9 | ('kavieng', 'pg')
# Processing Record 25 of Set 9 | ('biloela', 'au')
# Processing Record 26 of Set 9 | ('phan rang', 'vn')
# City ('phan rang', 'vn') not found. Skipping...
# Processing Record 27 of Set 9 | ('new castle', 'us')
# Processing Record 28 of Set 9 | ('brazzaville', 'cg')
# Processing Record 29 of Set 9 | ('kayes', 'ml')
# Processing Record 30 of Set 9 | ('waingapu', 'id')
# Processing Record 31 of Set 9 | ('yelatma', 'ru')
# Processing Record 32 of Set 9 | ('rawson', 'ar')
# Processing Record 33 of Set 9 | ('hami', 'cn')
# Processing Record 34 of Set 9 | ('phaltan', 'in')
# Processing Record 35 of Set 9 | ('geraldton', 'au')
# Processing Record 36 of Set 9 | ('lower hutt', 'nz')
# Processing Record 37 of Set 9 | ('vardo', 'no')
# Processing Record 38 of Set 9 | ('duobao', 'cn')
# Processing Record 39 of Set 9 | ('artyom', 'az')
# Processing Record 40 of Set 9 | ('ust-kamchatsk', 'ru')
# City ('ust-kamchatsk', 'ru') not found. Skipping...
# Processing Record 41 of Set 9 | ('kikwit', 'cd')
# Processing Record 42 of Set 9 | ('huicungo', 'pe')
# Processing Record 43 of Set 9 | ('chapleau', 'ca')
# Processing Record 44 of Set 9 | ('keuruu', 'fi')
# Processing Record 45 of Set 9 | ('agsu', 'az')
# City ('agsu', 'az') not found. Skipping...
# Processing Record 46 of Set 9 | ('shirokiy', 'ru')
# Processing Record 47 of Set 9 | ('kupang', 'id')
# Processing Record 48 of Set 9 | ('gravdal', 'no')
# Processing Record 49 of Set 9 | ('port lincoln', 'au')
# Processing Record 50 of Set 9 | ('kousseri', 'cm')
# Processing Record 1 of Set 10 | ('togur', 'ru')
# Processing Record 2 of Set 10 | ('ust-omchug', 'ru')
# Processing Record 3 of Set 10 | ('verkhnevilyuysk', 'ru')
# Processing Record 4 of Set 10 | ('cairns', 'au')
# Processing Record 5 of Set 10 | ('georgetown', 'sh')
# Processing Record 6 of Set 10 | ('ronne', 'dk')
# Processing Record 7 of Set 10 | ('turbat', 'pk')
# Processing Record 8 of Set 10 | ('dyakonovo', 'ru')
# City ('dyakonovo', 'ru') not found. Skipping...
# Processing Record 9 of Set 10 | ('college', 'us')
# Processing Record 10 of Set 10 | ('stanovoye', 'ru')
# Processing Record 11 of Set 10 | ('zurrieq', 'mt')
# Processing Record 12 of Set 10 | ('shadegan', 'ir')
# Processing Record 13 of Set 10 | ('malwan', 'in')
# City ('malwan', 'in') not found. Skipping...
# Processing Record 14 of Set 10 | ('kununurra', 'au')
# Processing Record 15 of Set 10 | ('kindu', 'cd')
# Processing Record 16 of Set 10 | ('manokwari', 'id')
# Processing Record 17 of Set 10 | ('kaeo', 'nz')
# Processing Record 18 of Set 10 | ('tasbuget', 'kz')
# City ('tasbuget', 'kz') not found. Skipping...
# Processing Record 19 of Set 10 | ('nokaneng', 'bw')
# Processing Record 20 of Set 10 | ('ekhabi', 'ru')
# Processing Record 21 of Set 10 | ('koeru', 'ee')
# Processing Record 22 of Set 10 | ('cayenne', 'gf')
# Processing Record 23 of Set 10 | ('jiwani', 'pk')
# Processing Record 24 of Set 10 | ('portland', 'au')
# Processing Record 25 of Set 10 | ('faya', 'td')
# Processing Record 26 of Set 10 | ('gat', 'ly')
# Processing Record 27 of Set 10 | ('grand baie', 'mu')
# Processing Record 28 of Set 10 | ('ucluelet', 'ca')
# Processing Record 29 of Set 10 | ('abu samrah', 'qa')
# Processing Record 30 of Set 10 | ('zhigalovo', 'ru')
# Processing Record 31 of Set 10 | ('saldanha', 'za')
# Processing Record 32 of Set 10 | ('fare', 'pf')
# Processing Record 33 of Set 10 | ('banda aceh', 'id')
# Processing Record 34 of Set 10 | ('kolaras', 'in')
# Processing Record 35 of Set 10 | ('dodge city', 'us')
# Processing Record 36 of Set 10 | ('smithers', 'ca')
# Processing Record 37 of Set 10 | ('sept-iles', 'ca')
# Processing Record 38 of Set 10 | ('tari', 'pg')
# Processing Record 39 of Set 10 | ('kahului', 'us')
# Processing Record 40 of Set 10 | ('puerto vallarta', 'mx')
# Processing Record 41 of Set 10 | ('cururupu', 'br')
# Processing Record 42 of Set 10 | ('ambon', 'id')
# Processing Record 43 of Set 10 | ('black river', 'jm')
# Processing Record 44 of Set 10 | ('qasigiannguit', 'gl')
# Processing Record 45 of Set 10 | ('pakxan', 'la')
# Processing Record 46 of Set 10 | ('tulun', 'ru')
# Processing Record 47 of Set 10 | ('eha amufu', 'ng')
# Processing Record 48 of Set 10 | ('ancud', 'cl')
# Processing Record 49 of Set 10 | ('hainichen', 'de')
# Processing Record 50 of Set 10 | ('macae', 'br')
# Processing Record 1 of Set 11 | ('vestmanna', 'fo')
# Processing Record 2 of Set 11 | ('narrabri', 'au')
# Processing Record 3 of Set 11 | ('kattivakkam', 'in')
# Processing Record 4 of Set 11 | ('port hawkesbury', 'ca')
# Processing Record 5 of Set 11 | ('funtua', 'ng')
# Processing Record 6 of Set 11 | ('walvis bay', 'na')
# Processing Record 7 of Set 11 | ('westport', 'nz')
# Processing Record 8 of Set 11 | ('kodiak', 'us')
# Processing Record 9 of Set 11 | ('hovd', 'mn')
# Processing Record 10 of Set 11 | ('srandakan', 'id')
# Processing Record 11 of Set 11 | ('atbasar', 'kz')
# Processing Record 12 of Set 11 | ('amvrosiyivka', 'ua')
# Processing Record 13 of Set 11 | ('bonthe', 'sl')
# Processing Record 14 of Set 11 | ('iranshahr', 'ir')
# Processing Record 15 of Set 11 | ('rio do sul', 'br')
# Processing Record 16 of Set 11 | ('shaoyang', 'cn')
# Processing Record 17 of Set 11 | ('iqaluit', 'ca')
# Processing Record 18 of Set 11 | ('kargapolye', 'ru')
# City ('kargapolye', 'ru') not found. Skipping...
# Processing Record 19 of Set 11 | ('broken hill', 'au')
# Processing Record 20 of Set 11 | ('isangel', 'vu')
# Processing Record 21 of Set 11 | ('tabiauea', 'ki')
# City ('tabiauea', 'ki') not found. Skipping...
# Processing Record 22 of Set 11 | ('mahebourg', 'mu')
# Processing Record 23 of Set 11 | ('henties bay', 'na')
# Processing Record 24 of Set 11 | ('greenville', 'us')
# Processing Record 25 of Set 11 | ('lorengau', 'pg')
# Processing Record 26 of Set 11 | ('arawa', 'pg')
# Processing Record 27 of Set 11 | ('qui nhon', 'vn')
# Processing Record 28 of Set 11 | ('general pico', 'ar')
# Processing Record 29 of Set 11 | ('bahawalnagar', 'pk')
# Processing Record 30 of Set 11 | ('saint-michel-des-saints', 'ca')
# Processing Record 31 of Set 11 | ('bhalki', 'in')
# Processing Record 32 of Set 11 | ('tongren', 'cn')
# Processing Record 33 of Set 11 | ('pangkalanbuun', 'id')
# Processing Record 34 of Set 11 | ('havre-saint-pierre', 'ca')
# Processing Record 35 of Set 11 | ('arys', 'kz')
# Processing Record 36 of Set 11 | ('pombia', 'gr')
# Processing Record 37 of Set 11 | ('fenoarivo atsinanana', 'mg')
# Processing Record 38 of Set 11 | ('road town', 'vg')
# Processing Record 39 of Set 11 | ('rincon viejo', 'mx')
# Processing Record 40 of Set 11 | ('coihaique', 'cl')
# Processing Record 41 of Set 11 | ('wuwei', 'cn')
# Processing Record 42 of Set 11 | ('kjollefjord', 'no')
# Processing Record 43 of Set 11 | ('joshimath', 'in')
# Processing Record 44 of Set 11 | ('ketchikan', 'us')
# Processing Record 45 of Set 11 | ('alakurtti', 'ru')
# Processing Record 46 of Set 11 | ('praya', 'id')
# Processing Record 47 of Set 11 | ('flinders', 'au')
# Processing Record 48 of Set 11 | ('bay saint louis', 'us')
# Processing Record 49 of Set 11 | ('bandarbeyla', 'so')
# Processing Record 50 of Set 11 | ('redcar', 'gb')
# Processing Record 1 of Set 12 | ('severo-yeniseyskiy', 'ru')
# Processing Record 2 of Set 12 | ('surt', 'ly')
# Processing Record 3 of Set 12 | ('beringovskiy', 'ru')
# Processing Record 4 of Set 12 | ('lapeer', 'us')
# Processing Record 5 of Set 12 | ('san luis', 'gt')
# Processing Record 6 of Set 12 | ('ilo', 'pe')
# Processing Record 7 of Set 12 | ('wanxian', 'cn')
# Processing Record 8 of Set 12 | ('bonoua', 'ci')
# Processing Record 9 of Set 12 | ('sisimiut', 'gl')
# Processing Record 10 of Set 12 | ('tura', 'ru')
# Processing Record 11 of Set 12 | ('mitu', 'co')
# Processing Record 12 of Set 12 | ('anaco', 've')
# Processing Record 13 of Set 12 | ('hofn', 'is')
# Processing Record 14 of Set 12 | ('hit', 'iq')
# Processing Record 15 of Set 12 | ('galiwinku', 'au')
# City ('galiwinku', 'au') not found. Skipping...
# Processing Record 16 of Set 12 | ('tuntum', 'br')
# Processing Record 17 of Set 12 | ('orbetello', 'it')
# Processing Record 18 of Set 12 | ('maseru', 'ls')
# Processing Record 19 of Set 12 | ('moindou', 'nc')
# Processing Record 20 of Set 12 | ('mwanga', 'tz')
# Processing Record 21 of Set 12 | ('marfino', 'ru')
# Processing Record 22 of Set 12 | ('sulzbach-rosenberg', 'de')
# Processing Record 23 of Set 12 | ('louisbourg', 'ca')
# City ('louisbourg', 'ca') not found. Skipping...
# Processing Record 24 of Set 12 | ('ingleside', 'us')
# Processing Record 25 of Set 12 | ('luanda', 'ao')
# Processing Record 26 of Set 12 | ('zyryanka', 'ru')
# Processing Record 27 of Set 12 | ('nalut', 'ly')
# Processing Record 28 of Set 12 | ('mbandaka', 'cd')
# Processing Record 29 of Set 12 | ('labytnangi', 'ru')
# Processing Record 30 of Set 12 | ('yarada', 'in')
# Processing Record 31 of Set 12 | ('avera', 'pf')
# Processing Record 32 of Set 12 | ('shahrud', 'ir')
# Processing Record 33 of Set 12 | ('buta', 'cd')
# Processing Record 34 of Set 12 | ('alofi', 'nu')
# Processing Record 35 of Set 12 | ('sorong', 'id')
# Processing Record 36 of Set 12 | ('baruun-urt', 'mn')
# Processing Record 37 of Set 12 | ('ugoofaaru', 'mv')
# Processing Record 38 of Set 12 | ('lasa', 'cn')
# Processing Record 39 of Set 12 | ('hackettstown', 'us')
# Processing Record 40 of Set 12 | ('klaksvik', 'fo')
# Processing Record 41 of Set 12 | ('guatire', 've')
# Processing Record 42 of Set 12 | ('abu dhabi', 'ae')
# Processing Record 43 of Set 12 | ('canapi', 'br')
# Processing Record 44 of Set 12 | ('toora-khem', 'ru')
# Processing Record 45 of Set 12 | ('lolua', 'tv')
# City ('lolua', 'tv') not found. Skipping...
# Processing Record 46 of Set 12 | ('puerto plata', 'do')
# Processing Record 47 of Set 12 | ('saint george', 'bm')
# Processing Record 48 of Set 12 | ('verkhoyansk', 'ru')
# Processing Record 49 of Set 12 | ('medicine hat', 'ca')
# Processing Record 50 of Set 12 | ('kemin', 'kg')
# Processing Record 1 of Set 13 | ('kasempa', 'zm')
# Processing Record 2 of Set 13 | ('cap malheureux', 'mu')
# Processing Record 3 of Set 13 | ('mancio lima', 'br')
# Processing Record 4 of Set 13 | ('puerto carreno', 'co')
# Processing Record 5 of Set 13 | ('bokspits', 'bw')
# City ('bokspits', 'bw') not found. Skipping...
# Processing Record 6 of Set 13 | ('vung tau', 'vn')
# Processing Record 7 of Set 13 | ('zarichne', 'ua')
# Processing Record 8 of Set 13 | ('kenai', 'us')
# Processing Record 9 of Set 13 | ('port macquarie', 'au')
# Processing Record 10 of Set 13 | ('koslan', 'ru')
# Processing Record 11 of Set 13 | ('sistranda', 'no')
# Processing Record 12 of Set 13 | ('ayan', 'ru')
# Processing Record 13 of Set 13 | ('andenes', 'no')
# Processing Record 14 of Set 13 | ('sibenik', 'hr')
# Processing Record 15 of Set 13 | ('abong mbang', 'cm')
# Processing Record 16 of Set 13 | ('santa maria da vitoria', 'br')
# Processing Record 17 of Set 13 | ('lalmohan', 'bd')
# Processing Record 18 of Set 13 | ('bourail', 'nc')
# Processing Record 19 of Set 13 | ('burayevo', 'ru')
# Processing Record 20 of Set 13 | ('cascais', 'pt')
# Processing Record 21 of Set 13 | ('vicosa', 'br')
# Processing Record 22 of Set 13 | ('floro', 'no')
# Processing Record 23 of Set 13 | ('westport', 'ie')
# Processing Record 24 of Set 13 | ('mariana', 'br')
# Processing Record 25 of Set 13 | ('galle', 'lk')
# Processing Record 26 of Set 13 | ('alice springs', 'au')
# Processing Record 27 of Set 13 | ('bar harbor', 'us')
# Processing Record 28 of Set 13 | ('san policarpo', 'ph')
# Processing Record 29 of Set 13 | ('yantal', 'ru')
# Processing Record 30 of Set 13 | ('lerwick', 'gb')
# Processing Record 31 of Set 13 | ('adrar', 'dz')
# Processing Record 32 of Set 13 | ('toliary', 'mg')
# City ('toliary', 'mg') not found. Skipping...
# Processing Record 33 of Set 13 | ('osoyoos', 'ca')
# Processing Record 34 of Set 13 | ('luau', 'ao')
# Processing Record 35 of Set 13 | ('solnechnyy', 'ru')
# Processing Record 36 of Set 13 | ('zholymbet', 'kz')
# Processing Record 37 of Set 13 | ('ust-nera', 'ru')
# Processing Record 38 of Set 13 | ('karwar', 'in')
# Processing Record 39 of Set 13 | ('bitam', 'ga')
# Processing Record 40 of Set 13 | ('lodwar', 'ke')
# Processing Record 41 of Set 13 | ('bani', 'do')
# Processing Record 42 of Set 13 | ('kiama', 'au')
# Processing Record 43 of Set 13 | ('phalombe', 'mw')
# Processing Record 44 of Set 13 | ('starobaltachevo', 'ru')
# Processing Record 45 of Set 13 | ('poum', 'nc')
# Processing Record 46 of Set 13 | ('sakaiminato', 'jp')
# Processing Record 47 of Set 13 | ('aleksandrovskoye', 'ru')
# Processing Record 48 of Set 13 | ('qingan', 'cn')
# City ('qingan', 'cn') not found. Skipping...
# Processing Record 49 of Set 13 | ('aripuana', 'br')
# Processing Record 50 of Set 13 | ('mitsamiouli', 'km')
# Processing Record 1 of Set 14 | ('tilichiki', 'ru')
# Processing Record 2 of Set 14 | ('brigantine', 'us')
# Processing Record 3 of Set 14 | ('pinawa', 'ca')
# Processing Record 4 of Set 14 | ('barbar', 'sd')
# City ('barbar', 'sd') not found. Skipping...
# Processing Record 5 of Set 14 | ('leh', 'in')
# Processing Record 6 of Set 14 | ('harper', 'lr')
# Processing Record 7 of Set 14 | ('hamilton', 'us')
# Processing Record 8 of Set 14 | ('groa', 'no')
# Processing Record 9 of Set 14 | ('yulara', 'au')
# Processing Record 10 of Set 14 | ('sarankhola', 'bd')
# Processing Record 11 of Set 14 | ('porto walter', 'br')
# Processing Record 12 of Set 14 | ('te anau', 'nz')
# Processing Record 13 of Set 14 | ('nerchinsk', 'ru')
# Processing Record 14 of Set 14 | ('gimli', 'ca')
# Processing Record 15 of Set 14 | ('balaipungut', 'id')
# Processing Record 16 of Set 14 | ('tokur', 'ru')
# Processing Record 17 of Set 14 | ('savannah bight', 'hn')
# Processing Record 18 of Set 14 | ('mayor pablo lagerenza', 'py')
# Processing Record 19 of Set 14 | ('olinda', 'br')
# Processing Record 20 of Set 14 | ('tocopilla', 'cl')
# Processing Record 21 of Set 14 | ('saint-pierre', 'pm')
# Processing Record 22 of Set 14 | ('qostanay', 'kz')
# Processing Record 23 of Set 14 | ('mobaye', 'cf')
# Processing Record 24 of Set 14 | ('dicabisagan', 'ph')
# Processing Record 25 of Set 14 | ('batangafo', 'cf')
# Processing Record 26 of Set 14 | ('hervey bay', 'au')
# Processing Record 27 of Set 14 | ('nordfjordeid', 'no')
# Processing Record 28 of Set 14 | ('rio tuba', 'ph')
# Processing Record 29 of Set 14 | ('grand centre', 'ca')
# City ('grand centre', 'ca') not found. Skipping...
# Processing Record 30 of Set 14 | ('tuggurt', 'dz')
# City ('tuggurt', 'dz') not found. Skipping...
# Processing Record 31 of Set 14 | ('bowen', 'au')
# Processing Record 32 of Set 14 | ('luena', 'ao')
# Processing Record 33 of Set 14 | ('vysokogornyy', 'ru')
# Processing Record 34 of Set 14 | ('sochaczew', 'pl')
# Processing Record 35 of Set 14 | ('aksarayskiy', 'ru')
# Processing Record 36 of Set 14 | ('ravar', 'ir')
# Processing Record 37 of Set 14 | ('batemans bay', 'au')
# Processing Record 38 of Set 14 | ('erzurum', 'tr')
# Processing Record 39 of Set 14 | ('yelovo', 'ru')
# Processing Record 40 of Set 14 | ('manicore', 'br')
# Processing Record 41 of Set 14 | ('aklavik', 'ca')
# Processing Record 42 of Set 14 | ('clarence town', 'bs')
# Processing Record 43 of Set 14 | ('mildura', 'au')
# Processing Record 44 of Set 14 | ('teodoro sampaio', 'br')
# Processing Record 45 of Set 14 | ('asau', 'tv')
# City ('asau', 'tv') not found. Skipping...
# Processing Record 46 of Set 14 | ('kamenskoye', 'ru')
# City ('kamenskoye', 'ru') not found. Skipping...
# Processing Record 47 of Set 14 | ('ust-kuyga', 'ru')
# Processing Record 48 of Set 14 | ('cockburn town', 'bs')
# Processing Record 49 of Set 14 | ('hihifo', 'to')
# City ('hihifo', 'to') not found. Skipping...
# Processing Record 50 of Set 14 | ('pucara', 'pe')
# Processing Record 1 of Set 15 | ('taoudenni', 'ml')
# Processing Record 2 of Set 15 | ('gorontalo', 'id')
# Processing Record 3 of Set 15 | ('beira', 'mz')
# Processing Record 4 of Set 15 | ('kaolinovo', 'bg')
# Processing Record 5 of Set 15 | ('birjand', 'ir')
# Processing Record 6 of Set 15 | ('kuvandyk', 'ru')
# Processing Record 7 of Set 15 | ('laramie', 'us')
# Processing Record 8 of Set 15 | ('khonuu', 'ru')
# City ('khonuu', 'ru') not found. Skipping...
# Processing Record 9 of Set 15 | ('skagastrond', 'is')
# City ('skagastrond', 'is') not found. Skipping...
# Processing Record 10 of Set 15 | ('komsomolskiy', 'ru')
# Processing Record 11 of Set 15 | ('bargal', 'so')
# City ('bargal', 'so') not found. Skipping...
# Processing Record 12 of Set 15 | ('alyth', 'gb')
# Processing Record 13 of Set 15 | ('bintulu', 'my')
# Processing Record 14 of Set 15 | ('mangrol', 'in')
# Processing Record 15 of Set 15 | ('saint george', 'us')
# Processing Record 16 of Set 15 | ('lokosovo', 'ru')
# Processing Record 17 of Set 15 | ('swan river', 'ca')
# Processing Record 18 of Set 15 | ('sao miguel', 'br')
# Processing Record 19 of Set 15 | ('severodvinsk', 'ru')
# Processing Record 20 of Set 15 | ('rosarito', 'mx')
# Processing Record 21 of Set 15 | ('bati', 'et')
# Processing Record 22 of Set 15 | ('corinto', 'ni')
# Processing Record 23 of Set 15 | ('zhezkazgan', 'kz')
# Processing Record 24 of Set 15 | ('emirdag', 'tr')
# Processing Record 25 of Set 15 | ('vydrino', 'ru')
# Processing Record 26 of Set 15 | ('santa vitoria', 'br')
# Processing Record 27 of Set 15 | ('marquette', 'us')
# Processing Record 28 of Set 15 | ('general roca', 'ar')
# Processing Record 29 of Set 15 | ('majene', 'id')
# Processing Record 30 of Set 15 | ('aborlan', 'ph')
# Processing Record 31 of Set 15 | ('lisakovsk', 'kz')
# Processing Record 32 of Set 15 | ('bath', 'us')
# Processing Record 33 of Set 15 | ('nantucket', 'us')
# Processing Record 34 of Set 15 | ('kadykchan', 'ru')
# City ('kadykchan', 'ru') not found. Skipping...
# Processing Record 35 of Set 15 | ('scarborough', 'tt')
# Processing Record 36 of Set 15 | ('darnah', 'ly')
# Processing Record 37 of Set 15 | ('sabang', 'id')
# Processing Record 38 of Set 15 | ('tucupita', 've')
# Processing Record 39 of Set 15 | ('north bend', 'us')
# Processing Record 40 of Set 15 | ('nouadhibou', 'mr')
# Processing Record 41 of Set 15 | ('haradok', 'by')
# Processing Record 42 of Set 15 | ('burhaniye', 'tr')
# Processing Record 43 of Set 15 | ('wenchi', 'gh')
# Processing Record 44 of Set 15 | ('semey', 'kz')
# Processing Record 45 of Set 15 | ('gemena', 'cd')
# Processing Record 46 of Set 15 | ('cajaruro', 'pe')
# Processing Record 47 of Set 15 | ('vittorio veneto', 'it')
# Processing Record 48 of Set 15 | ('kaka', 'tm')
# Processing Record 49 of Set 15 | ('la crosse', 'us')
# Processing Record 50 of Set 15 | ('praia', 'cv')
# Processing Record 1 of Set 16 | ('ystad', 'se')
# Processing Record 2 of Set 16 | ('samusu', 'ws')
# City ('samusu', 'ws') not found. Skipping...
# Processing Record 3 of Set 16 | ('domoni', 'km')
# Processing Record 4 of Set 16 | ('dakar', 'sn')
# Processing Record 5 of Set 16 | ('baiquan', 'cn')
# Processing Record 6 of Set 16 | ('siljan', 'no')
# Processing Record 7 of Set 16 | ('deep river', 'ca')
# Processing Record 8 of Set 16 | ('otse', 'bw')
# Processing Record 9 of Set 16 | ('bollnas', 'se')
# Processing Record 10 of Set 16 | ('kudahuvadhoo', 'mv')
# Processing Record 11 of Set 16 | ('sangmelima', 'cm')
# Processing Record 12 of Set 16 | ('gamba', 'ga')
# Processing Record 13 of Set 16 | ('mutis', 'co')
# Processing Record 14 of Set 16 | ('altay', 'cn')
# Processing Record 15 of Set 16 | ('otautau', 'nz')
# Processing Record 16 of Set 16 | ('waddan', 'ly')
# Processing Record 17 of Set 16 | ('sodertalje', 'se')
# City ('sodertalje', 'se') not found. Skipping...
# Processing Record 18 of Set 16 | ('bad wildungen', 'de')
# Processing Record 19 of Set 16 | ('mathbaria', 'bd')
# Processing Record 20 of Set 16 | ('solsvik', 'no')
# City ('solsvik', 'no') not found. Skipping...
# Processing Record 21 of Set 16 | ('mount isa', 'au')
# Processing Record 22 of Set 16 | ('muros', 'es')
# Processing Record 23 of Set 16 | ('grand-santi', 'gf')
# Processing Record 24 of Set 16 | ('daru', 'pg')
# Processing Record 25 of Set 16 | ('maumere', 'id')
# -----------------------------
# Data Retrieval Complete
# -----------------------------
